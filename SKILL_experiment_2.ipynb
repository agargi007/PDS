# %% [markdown]
# <a href="https://colab.research.google.com/github/agargi007/PDS/blob/main/SKILL_experiment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SKILL expriment 2:
#
# 1. Imoprting neccessary libraries (like pandas and numpy here)
# 2. Import the two datasets.
# 3. Perform data cleaning process:
#                                   1. Remove all the null values from the merged and concatinated data.
#                                   2. Find information of the data by the .info () function in python.
#                                   3. Describe the datasets using .describe() function in python.
#                                   4. Check whether there exist any null or missing values in the datasets by using .isnull().any() function.
#                                   5. Check for duplicate values in the datasets if any using .duplicated() function.
#                                   6. Drop the duplicate values from the datasets using the drop_duplicates() function.
#                                   7. Fill the missing values (null values) with some value .
#                                   8. Count the non-null values from any particular column from any dataset by specifying the column name.

# %%
import pandas as pd#importing the pandas lib
import numpy as np#importing nnumpy lib

url1 = "/content/sample_data/california_housing_test.csv"# url for dataset1
data1 = pd.read_csv(url1) #reading the dataset

url2 = "/content/sample_data/california_housing_train.csv"# url for dataset2
data2 = pd.read_csv(url2)#reading dataset 2

cc_data = pd.concat([data1, data2], ignore_index=True)

merge_data = pd.merge(data1, data2, how="outer", on=["longitude", "latitude"])

print("removing null values from data 1")
data1.dropna(axis=0,inplace=True)
print (data1)

print("removing null values from data2")
data2.dropna(axis=0,inplace=True)
print (data2)

print("removing null values from merged datasets:")
merge_data.dropna(axis=0 ,  inplace=True)
print(merge_data)

print("removing null values from concatenated datasets:")
cc_data.dropna(axis=0 ,  inplace=True)
print(cc_data)
# Out:
# removing null values from data 1
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
import pandas as pd#importing the pandas lib
import numpy as np#importing nnumpy lib

url1 = "/content/sample_data/california_housing_test.csv"# url for dataset1
data1 = pd.read_csv(url1) #reading the dataset

url2 = "/content/sample_data/california_housing_train.csv"# url for dataset2
data2 = pd.read_csv(url2)#reading dataset 2
print("information of datasets")
print(data1.info())
print(data2.info())
print("describing datasets")
print(data1.describe())

print("check is null")
print(data1.isnull().any())
print("duplicated")
print(data1.duplicated())
print("drop duplicates")
print(data1.drop_duplicates(inplace=True))
print("fillna")
data1['latitude'].fillna(data1['latitude'].mean(), inplace=True)
print(data1[['latitude']])
print("\n couhnting \n")
data1['latitude'].count()
# Out:
# information of datasets
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
# ...

# %%
import pandas as pd
import numpy as np


url1 = "/content/sample_data/california_housing_test.csv"
data1 = pd.read_csv(url1)

url2 = "/content/sample_data/california_housing_train.csv"
data2 = pd.read_csv(url2)


print("Information of datasets:")
print("Dataset 1 info:")
print(data1.info())

print("\nDataset 2 info:")
print(data2.info())

print("\nDescribing datasets:")
print(data1.describe())

print("\nCheck if there are missing values in dataset 1:")
print(data1.isnull().any())

print("\nChecking for duplicates in dataset 1:")
print(data1.duplicated())

data1.drop_duplicates(inplace=True)
print("\nAfter dropping duplicates:")
print(data1.info())

print("\nFilling missing values in 'latitude' with the mean value:")
data1['latitude'].fillna(data1['latitude'].mean(), inplace=True)
print(data1[['latitude']].head())

print("\nCounting non-null values in 'latitude' column:")
print(data1['latitude'].count())
# Out:
# Information of datasets:
# Dataset 1 info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB
# None
#
# Dataset 2 info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
# ...
